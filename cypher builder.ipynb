# %%
#!/usr/bin/python
# coding: UTF-8
f = open('neo4j_movie_standby.txt')
data = f.read()
f.close()
lines = data.split('\n')

# %%
import re

new_lines = []
for line in lines:
    line = re.sub('title',  'en_name', line)
    line = re.sub('tagline',  'en_description', line)
    line = re.sub('released',  'start', line)
    line = re.sub('born',  'start', line)
    line = re.sub('start: ?(\d{4})',  r' start: datetime("\1-01-01T00:00:00"), start_accuracy: "year"', line)
    new_lines.append(line)

for new_line in new_lines:
    print (new_line)
# Out:
# CREATE (TheMatrix:Movie {en_name:'The Matrix', name: 'マトリックス', image_path: 'https://images.ciatr.jp/2017/07/w_828/0kDnZaTrd4xrWWav8PB8XIVBRXoQGsWGgNSdnp2E.jpeg',  start: datetime("1999-01-01T00:00:00"), start_accuracy: "year", is_momentary: TRUE, en_description:'Welcome to the Real World'})
# CREATE (Keanu:Person {en_name:'Keanu Reeves', name: 'キアヌ・リーブス', image_path: 'https://eiga.k-img.com/images/person/25800/42f4404d90650ae2/320.jpg',  start: datetime("1964-01-01T00:00:00"), start_accuracy: "year", is_momentary: TRUE})
# CREATE (Carrie:Person {en_name:'Carrie-Anne Moss', name: 'キャリー・アン・モス', image_path: 'https://pmctvline2.files.wordpress.com/2019/07/carrie-anne-moss.jpg',  start: datetime("1967-01-01T00:00:00"), start_accuracy: "year", is_momentary: TRUE})
# ...
